# %% [markdown]
# <a href="https://colab.research.google.com/github/nichakornchaisuwan/data_viz_2022/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #  import แพ็กเกจที่สำคัญ

# %% [markdown]
# .csv  = comma separated values ข้อมูลที่ถูกแบ่งด้วย , (comma)

# %% [markdown]
# data.go.th (แหล่งข้อมูล)

# %%
from google.colab import drive
drive.mount('/content/drive')  #เป็นการเชื่อมต่อ colab เข้ากับ drive ข้อมูล
# Out:
# Mounted at /content/drive

# %%
import os  # ใช้จัดการกับไฟล์ต่าง ว่าไฟล์อยู่ที่ไหน

# %%
path = '/content/drive/My Drive/dataviz_2021_data'  # ชี้ว่าไฟล์อยู่ที่ไหน

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv')  # os.path.join เป็นการเชื่อมต่อไฟล์
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv' 
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-2021.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)  # pd.read_csv เป็นการอ่านข้อมูล แล้วตั้งชื่อตัวแปรที่เก็บไว้ว่า data_covid
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data_covid.head() # .head ใช้ดูหัวตาราง
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid.head(20) # .head ใช้ดูหัวตาราง
# Out:
#     No.  ...                                               risk
# 0     1  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1     2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2     3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3     4  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4     5  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 5     6  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 6     7  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7     8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 8     9  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 9    10  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 10   11  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11   12  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12   13  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13   14  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...

# %%
data_covid.tail() # .tail ใช้ดูท้ายตาราง
# Out:
#          No.  ...                                         risk
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %%
data_covid.shape # แสดงว่าข้อมูลมีกี่แถว กี่คอลัมน์
# Out:
# (12653, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_onset'] #ต้องการดูแค่บางคอลัมน์
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset'][4] #ชี้ชื่อคอลัมน์ก่อน แล้วตามด้วยลำดับของแถว
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7] # .iloc เปลี่ยนการมองเห็นจากตาราง ให้เป็น array แล้วตามด้วยการชี้ไปยังข้อมูล แถว,หลัก
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']] # [[ใส่ชื่อคอลัมน์ที่ต้องการ ตามลำลับที่ต้องการได้]]
smaller_table
# Out:
#       announce_date  ...                                         risk
# 0         1/12/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         1/17/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         1/24/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...             ...  ...                                          ...
# 12648     1/20/2021  ...                             State Quarantine
# 12649     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651     1/20/2021  ...                                Cluster ระยอง
# 12652     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 3 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:] # แถวที่ 1-4 ทุก คอลัมน์
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# $pddf$[list_of_logical_values] คือการเลือก row ที่ logical values เป็น True

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset']=='ขอนแก่น'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น'] # ชื่อตาราง ['ชื่อคอลัมน์']=='สิ่งที่ต้องการค้นหา'
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
data_covid[data_covid['age']>=70] # อายุมากกว่า 70
# Out:
#          No.  ...                                               risk
# 1          2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7          8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 24        25  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 82        83  ...                                            สนามมวย
# ...      ...  ...                                                ...
# 11694  11695  ...      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 11700  11701  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11730  11731  ...                                  Cluster สมุทรสาคร
# 11741  11742  ...                               อยู่ระหว่างการสอบสวน
# 12102  12103  ...                                  Cluster สมุทรสาคร
#
# [245 rows x 10 columns]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,3:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7  หญิง  73.0  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 7 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ list ที่มีค่า logic ของแต่ละ  rows โดยที่ค่า True คือ เลือก ค่า Fales คือ ไม่เลือก
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 7 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 7 columns]

# %% [markdown]
# $ .isnull() $ ใช้ตรวจสอบว่าเป็น NaN หรือไม่

# %%
eight_rows_covid['district_of_onset'] .isnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: district_of_onset, dtype: bool

# %% [markdown]
# HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น
# 3.    หาจำนวนผู้ป่วยที่เป็นคนไม่ใช่คนไทย

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
sum = 0
N = 0
for a in female['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %%
# 1.   คำนวณ อายุเฉลี่ย ของผู้ชาย ของข้อมูลทั้งหมด
data_1 = data_covid[['sex','age','province_of_onset']] # เลือกข้อมูลที่ต้องการจากตาราง data_covid ซึ่งประกอบไปด้วยคอลัมน์ เพศ(sex),อายุ(age),จังหวัด(province_of_onset) นำมาเก็บไว้ในตัวแปรที่ชื่อ data_1
data_1 # ทำการแสดงข้อมูลที่อยู่ในตัวแปร data_1 มีทั้งหมด 3 คอลัมน์
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
data_male = data_1[data_1['sex']=='ชาย'] # ดึงข้อมูลจาก data_1 โดยเลือกข้อมูลในนคอลัมน์ sex มาเฉพาะค่าที่เป็น 'ชาย' เท่านั้น แล้วนำไปเก็บไว้ที่ตัวแปร data_male
data_male# ทำการแสดงข้อมูลที่อยู่ในตัวแปร data_male ที่มีแค่เพศชาย
# Out:
#        sex   age province_of_onset
# 3      ชาย  68.0     กรุงเทพมหานคร
# 8      ชาย  63.0     กรุงเทพมหานคร
# 10     ชาย  33.0     กรุงเทพมหานคร
# 11     ชาย  61.0     กรุงเทพมหานคร
# 12     ชาย   6.0     กรุงเทพมหานคร
# ...    ...   ...               ...
# 12640  ชาย  66.0   พระนครศรีอยุธยา
# 12641  ชาย  29.0          ปทุมธานี
# 12643  ชาย  39.0              สตูล
# 12646  ชาย  18.0       สมุทรปราการ
# 12647  ชาย  42.0     กรุงเทพมหานคร
#
# [4819 rows x 3 columns]

# %%
data_male['age'] # ทำการแสดงข้อมูลที่อยู่ในตัวแปร data_male โดยเลือกมาเฉพาะคอลัมน์อายุ(age) โดยจะนำต้วเลขที่อยู่ในคอลัมน์อายุ ไปคำนวนหาค่าเฉลี่ยของอายุผู้ป่วยชาย
# Out:
# 3        68.0
# 8        63.0
# 10       33.0
# 11       61.0
# 12        6.0
#          ...
# 12640    66.0
# 12641    29.0
# 12643    39.0
# 12646    18.0
# 12647    42.0
# Name: age, Length: 4819, dtype: float64

# %%
# การบวกเริ่มที่ 0 การคูณเริ่มที่ 1
#การหาค่าเฉลี่ยอายุเกิดจากการเอาข้อมูลอายุมาบวกกัน แล้วหารด้วยจำนวนข้อมูลทั้งหมด เริ่มจาก
sum = 0  # ก่อนจะเอาค่ามาบวกกันได้ ต้องสร้างตัวแปรมารับก่อน จึงสร้างตัวแปร sum ขึ้นมา โดยกำหนดให้เท่ากับ 0  และเมื่อมีข้อมูลเข้ามาก็จะทำการบวกเพิ่มเข้าไปในตัวแปร sum เรื่อยๆ
N = 0 # จำนวนข้อมูลทั้งหมด โดยจะนับว่ามีอายุที่เอามาบวกกันกี่ค่า
for a in data_male['age']: # วนลูปค่าอายุแต่ละค่า โดยมาจากคอลัมน์ age
    
    if a > 0: # ทำการตรวจสอบก่อน โดยถ้าอายุมากกว่า 0 คือข้อมูลที่มีค่าปกติ ไม่มีข้อผิดพลาด
        sum += a # หากข้อมูลมีค่ามากกว่า 0 จะนำมาบวกเข้าใน ตัวแปร sum คือ sum + a
        N += 1 #จำนวนข้อมูลที่เข้ามาในแต่ละครั้ง โดยการบวกเข้าที่ละ 1 จนครบ

print(f'อายุเฉลี่ย ของ ผู้ป่วยชาย {sum/N}') #แสดงอายุเฉลี่ยของผู้ป่วยชาย โดยการเอาผลรวมของอายุทั้งหมด หาร จำนวนข้อมูลทั้งหมด
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยชาย 39.46076940331987

# %%
# 2. คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น
data_1
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
data_malekk = data_male[data_male['province_of_onset']=='ขอนแก่น'] # ดึงข้อมูลจาก data_male โดยเลือกข้อมูลในนคอลัมน์ province_of_onset  มาเฉพาะค่าที่เป็น 'ขอนแก่น' เท่านั้น แล้วนำไปเก็บไว้ที่ตัวแปร data_malekk
data_malekk #  ทำการแสดงข้อมูลที่อยู่ในตัวแปร data_malekk ที่เป็นเพศชาย และอยู่ในจังหวัดขอนแก่น
# Out:
#        sex   age province_of_onset
# 180    ชาย  33.0           ขอนแก่น
# 1466   ชาย  19.0           ขอนแก่น
# 2673   ชาย  68.0           ขอนแก่น
# 9333   ชาย  17.0           ขอนแก่น
# 9334   ชาย  20.0           ขอนแก่น
# 10610  ชาย  17.0           ขอนแก่น
# 11517  ชาย  12.0           ขอนแก่น

# %%
sum = 0 # ก่อนจะเอาค่ามาบวกกันได้ ต้องสร้างตัวแปรมารับก่อน จึงสร้างตัวแปร sum ขึ้นมา โดยกำหนดให้เท่ากับ 0  และเมื่อมีข้อมูลเข้ามาก็จะทำการบวกเพิ่มเข้าไปในตัวแปร sum เรื่อยๆ
N = 0 # จำนวนข้อมูลทั้งหมด โดยจะนับว่ามีอายุที่เอามาบวกกันกี่ค่า
for a in data_malekk['age']: # วนลูปค่าอายุแต่ละค่า โดยมาจากคอลัมน์ age
    
    if a > 0: # ทำการตรวจสอบก่อน โดยถ้าอายุมากกว่า 0 คือข้อมูลที่มีค่าปกติ ไม่มีข้อผิดพลาด
        sum += a # หากข้อมูลมีค่ามากกว่า 0 จะนำมาบวกเข้าใน ตัวแปร sum คือ sum + a
        N += 1 #จำนวนข้อมูลที่เข้ามาในแต่ละครั้ง โดยการบวกเข้าที่ละ 1 จนครบ

print(f'อายุเฉลี่ย ของ ผู้ป่วยชาย ในจังหวัดขอนแก่น {sum/N}') #แสดงอายุเฉลี่ยของผู้ป่วยชายในจังหวัดขอนแก่น โดยการเอาผลรวมของอายุทั้งหมด หาร จำนวนข้อมูลทั้งหมด
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยชาย ในจังหวัดขอนแก่น 26.571428571428573

# %%
# 3. หาจำนวนผู้ป่วยที่เป็นคนไม่ใช่คนไทย
data_nationality = data_covid[['nationality']] #เลือกข้อมูลที่ต้องการจากตาราง data_covid โดยเลือกคอลัมน์ nationality และนำไปเก็บไว้ที่ตัวแปร data_nationality
data_nationality #แสดงข้อมูลจากตัวแปร data_nationality
# Out:
#       nationality
# 0           China
# 1           China
# 2        Thailand
# 3           China
# 4           China
# ...           ...
# 12648    Thailand
# 12649    Thailand
# 12650    Thailand
# 12651    Thailand
# 12652       Burma
#
# [12653 rows x 1 columns]

# %%
data_notthai = data_nationality[data_nationality['nationality']!='Thailand'] # ดึงข้อมูลจาก data_nationlity โดยเลือกข้อมูลในนคอลัมน์ nationality  มาเฉพาะค่าที่ 'ไม่ใช่คนไทย'  แล้วนำไปเก็บไว้ที่ตัวแปร data_notthai
data_notthai #ทำการแสดงข้อมูลที่อยู่ในตัวแปร data_notthai ทั้งหมด
# Out:
#       nationality
# 0           China
# 1           China
# 3           China
# 4           China
# 5           China
# ...           ...
# 12614       Burma
# 12615       Burma
# 12617     Ireland
# 12618    Pakistan
# 12652       Burma
#
# [5340 rows x 1 columns]

# %%
data_notthaicount = data_notthai.count() # .count  ใช้นับจำนวนข้อมูลที่มีอยู่ในตาราง data_notthai ว่ามีทั้งหมดกี่ค่า
data_notthaicount # แสดงค่าที่นับได้ โดยนับได้ทั้งหมด 4129 ค่า
# Out:
# nationality    4129
# dtype: int64

# %%
notthai_NaN = data_notthai.isnull().sum() #.isnull() ใช้แสดงว่าข้อมูลในแต่ละแถวว่ามีค่า NaN  หรือไม่ ถ้ามี จะแสดลงผลว่า true ถ้าไม่มีจะแสดงผลว่า false จากนั้นใช้คำสั่ง .sum() เพื่อหาผลรวมของค่าNaN ว่ามีทั้งหมดกี่ค่า
notthai_NaN # แสดงผลรวมของค่า NaN โดยมีทั้งหมด 1211 ค่า
# Out:
# nationality    1211
# dtype: int64

# %%
data_notthai['nationality'].isnull() # false ไม่เป็นค่าว่าง
# Out:
# 0        False
# 1        False
# 3        False
# 4        False
# 5        False
#          ...
# 12614    False
# 12615    False
# 12617    False
# 12618    False
# 12652    False
# Name: nationality, Length: 5340, dtype: bool

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
this_data.shape #(12423, 3)
# Out:
# (12653, 3)

# %%
this_data.dropna()
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8478 rows x 3 columns]

# %%
print(data_covid.shape) #ยิ่งข้อมูลเยอะยิ่งมีค่าว่างเยอะ
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna(subset=['age','sex']) #สนใจแค่สองคอลัมน์นี้ ถ้ามีค่า missing ให้ตัดออก ถ้ามี ค่า missing ที่คอลัมน์อื่นก็จะไม่สนใจ
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %%
print(this_data.dropna().shape)
print(this_data.dropna(subset=['sex','age']).shape)
# Out:
# (8478, 3)
# (8880, 3)

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
this_data.isnull()
# Out:
#          sex    age  province_of_onset
# 0      False  False              False
# 1      False  False              False
# 2      False  False              False
# 3      False  False              False
# 4      False  False              False
# ...      ...    ...                ...
# 12648  False  False              False
# 12649  False  False              False
# 12650  False  False              False
# 12651  False  False              False
# 12652  False  False              False
#
# [12653 rows x 3 columns]

# %%
this_data.isnull().any() #เอาค่าความจริงในคอลัมน์ทั้งหมดมา or กัน ถ้ามี true 1 อันจะแสดงค่า true เลย
# Out:
# sex                  True
# age                  True
# province_of_onset    True
# dtype: bool

# %%
this_data.isnull().all() #เอาค่าความจริงในคอลัมน์มา and กัน
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %%
this_data.isnull().any().any() #ตารางนี้ค่าว่าง
# Out:
# True

# %%
this_data.dropna(subset=['age','sex']).isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# 1. เพื่อให้ได้ผลลัพธ์การจัดกำร dropna() ต้องเอาตัวแปรมารับ

# %%
this_data_nonull=this_data.dropna(subset=['age','sex'])

# %%
this_data_nonull.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# 2. update ตารางด้วยตัวแปร ```inplase```

# %%
this_data.dropna(subset=['age','sex'],inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna()```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %% [markdown]
# ### 1. แทนด้วย class ใหม่

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'}) # สร้าง class ใหม่ เพื่อไม่ให้รบกวนข้อมูลที่มีอยู่
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated.tail(15)
# Out:
#           sex   age province_of_onset
# 12638  ไม่รู้  -1.0         สมุทรสาคร
# 12639  ไม่รู้  -1.0         สมุทรสาคร
# 12640     ชาย  66.0   พระนครศรีอยุธยา
# 12641     ชาย  29.0          ปทุมธานี
# 12642    หญิง  50.0           ราชบุรี
# 12643     ชาย  39.0              สตูล
# 12644    หญิง  49.0       สมุทรปราการ
# 12645    หญิง  44.0            ชลบุรี
# 12646     ชาย  18.0       สมุทรปราการ
# 12647     ชาย  42.0     กรุงเทพมหานคร
# 12648    หญิง  44.0            ชลบุรี
# 12649    หญิง  52.0             ระยอง
# 12650    หญิง  23.0             ระยอง
# 12651    หญิง  29.0             ระยอง
# 12652    หญิง  22.0               ตาก

# %%
this_data_updated.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %% [markdown]
# ###2. แทนด้วยค่าที่เหมาะสม
#
# * ตามใจคนทำ
# * ค่ากลาง

# %% [markdown]
# ####ตามใจคนทำ

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid_fillasiwant=data_covid.fillna(value ={ 'sex' : 'หญิง'}) # เรามีข้อมูลว่าเพศหญิงเยอะกว่าเพศชาย

# %%
data_covid_fillasiwant.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                      False
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# ####แทนด้วยค่ากลาง

# %%
data_covid['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 3        68.0
# 4        66.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 12653, dtype: float64

# %%
data_covid['age'].mean()
# Out:
# 38.054748339151

# %%
data_covid_fillwithmean=data_covid.fillna(value ={ 'age' : data_covid['age'].mean()})

# %%
data_covid_fillwithmean.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                      False
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
for each_row in list(this_data.iterrows())[:5]:# ชื่อข้อมูล แล้วตามด้วย .iterrows
    #print(each_row)
    #print(each_row[1])
    #print(each_row[1] ['sex'])
    if (each_row[1]['age'] <= 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
       print(each_row)

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]): # 
    if (this_data.iloc[each_row,1] == 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %% [markdown]
# ## HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน anmounce_date เป็นวันที่ 1-20

# %%
an_date =list() # สร้าง list เปล่าขึ้นมา แล้วนำไปเก็บไว้ที่ตัวแปร an_data
for each_row in data_covid.iterrows(): # ไปดูทุกแถวในตาราง data_covid 
    if each_row[1]['announce_date'].split('/')[1] <= '20': #เป็นการดูแต่ละแถว, [1]['announce_date'] คือการเรียกดูข้อมูลเริ่มจากตัวที่ 1 ของแต่ละแถว และดูที่คอลัมน์ announce_date และแบ่งค่าข้อมูลโดยตัดตามเครื่องหมาย / เมื่อตัดแล้ว ตัวที่1 ของคอลัมน์ announce_date ต้องมีค่าน้อยกว่าหรือเท่ากับ 20
        an_date.append(True) # ถ้าข้อมูลตรงตามเงื่อนไข  จะทำการเพิ่มข้อมูลเข้าไปใน list an_date เป็นคำว่า true
    else:
        an_date.append(False) # ถ้าข้อมูลไม่ตรงตามเงื่อนไข จะเพิ่มข้อมูลเข้าไปใน list เป็นคำว่า false

data_covid[an_date] # แสดงค่าข้อมูลตาราง data_covid  #เวลาเลือก เลือกด้วยคำว่า true , false ข้อมูลในตางตางต้องเท่าเดิม
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32        33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33        34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34        35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5135 rows x 10 columns]

# %%
data_covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# 39.46076940331987

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
